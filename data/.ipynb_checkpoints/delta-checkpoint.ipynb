# %%
import pandas as pd
import numpy as np

# %%
temp = pd.read_csv('./temp_country_group.csv')
temp = temp.set_index(['ISO Code'])

# %%
temp_1950 = temp[[x >= 1950 for x in temp.dt]].reset_index()
temp_1950 = temp_1950.pivot(index='ISO Code', columns='dt', values='AverageTemperature')
delta_temp = temp_1950.copy()

for col in delta_temp.columns:
    delta_temp[col] = np.around(delta_temp[col] - temp2_1950[1950], decimals=5)

delta_temp = delta_temp.reset_index()
delta_temp.columns.name = ''

# %%
delta_temp.to_csv('delta_temp', encoding='utf-8', index=False)

# %%
pd.read_csv('delta_temp')
# Out:
#                                       ISO Code  1950     1951     1952  \
# 0                                          ABW   0.0  0.69317  1.01733
# 1                                          AFG   0.0  0.92425  1.13192
# 2                                          AGO   0.0  0.43033  0.61583
# 3                                          AIA   0.0  0.42883  0.60050
# 4                                          ALB   0.0 -0.24300 -0.23892
# 5                                          AND   0.0 -0.83908 -0.15117
# 6                                          ARE   0.0  0.76317  0.69200
# 7                                          ARG   0.0  0.04183  0.12125
# 8                                          ARM   0.0  0.52858  0.99700
# 9                                          ASM   0.0  0.16958  0.54367
# 10                                         ATG   0.0  0.48542  0.66192
# 11                                         AUS   0.0  0.23408  0.16408
# ...
